# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# TODO
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy import stats
from scipy.stats import iqr


distribucion_normal = np.random.normal(size=100)
distribucion_normal
plt.hist(distribucion_normal)
plt.show()

res = stats.shapiro(distribucion_normal)
res.statistic

chi_square = np.random.chisquare(3, size=100)
plt.hist(chi_square)
plt.show()

# Metricas Normales
media = np.mean(distribucion_normal)
desviacion = np.std(distribucion_normal)
print("Distribucion Normal")
print(f"La media es {media}")
print(f"La desviacion estandar es {desviacion}")


# Metricas No Normales
mediana = np.median(chi_square)
rango_intercuartilico = iqr(chi_square)
print("Distribucion No Normal")
print (f"La mediana es {mediana}")
print (f"El rango intercuartilico es {rango_intercuartilico}")
# Out:
# La media es0.02887060551700423
# La desviacion estandar es1.144625849967273
# La mediana es 2.4799556295808127
# El rango intercuartilico es 2.36843854655285

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# TODO
data = [4,2,5,8,6]
media = sum(data) / len(data)
tamaño = len(data)
sumatoria = 0
for n in (data):
    valor1 = (n - media)**2 
    sumatoria += valor1
desviacion_estandar = ((sumatoria)/tamaño)**0.5
print (f"la desviacion estandar es {desviacion_estandar}")

#Comparando con la funcion de Phyton
ds = np.std(data)
print (f"La comprobacion de la desviacion con respecto a la formula de Phyton {ds}")
# Out:
# la desviacion estandar es 2.0
# La comprobacion de la desviacion con respecto a la formula de Phyton 2.0
